# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
# load pima indians dataset
dataset = numpy.loadtxt('datasets/pima-indians-diabetes.csv', delimiter=',')

# %%
# split into input (X) and output (Y) variables
X = dataset[:,:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
# compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 12)                108
# _________________________________________________________________
# dense_7 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
# checkpoint
filepath = "models/pima_indians/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.67323, saving model to models/pima_indians/weights-improvement-01-0.67.hdf5
#
# Epoch 00002: val_accuracy improved from 0.67323 to 0.68110, saving model to models/pima_indians/weights-improvement-02-0.68.hdf5
#
# Epoch 00003: val_accuracy improved from 0.68110 to 0.68898, saving model to models/pima_indians/weights-improvement-03-0.69.hdf5
#
# Epoch 00004: val_accuracy did not improve from 0.68898
#
# Epoch 00005: val_accuracy did not improve from 0.68898
#
# Epoch 00006: val_accuracy improved from 0.68898 to 0.70079, saving model to models/pima_indians/weights-improvement-06-0.70.hdf5
#
# Epoch 00007: val_accuracy did not improve from 0.70079
#
# Epoch 00008: val_accuracy did not improve from 0.70079
#
# Epoch 00009: val_accuracy improved from 0.70079 to 0.71260, saving model to models/pima_indians/weights-improvement-09-0.71.hdf5
#
# Epoch 00010: val_accuracy improved from 0.71260 to 0.72047, saving model to models/pima_indians/weights-improvement-10-0.72.hdf5
#
# Epoch 00011: val_accuracy did not improve from 0.72047
#
# Epoch 00012: val_accuracy did not improve from 0.72047
#
# Epoch 00013: val_accuracy did not improve from 0.72047
#
# Epoch 00014: val_accuracy did not improve from 0.72047
#
# Epoch 00015: val_accuracy did not improve from 0.72047
#
# Epoch 00016: val_accuracy did not improve from 0.72047
#
# Epoch 00017: val_accuracy improved from 0.72047 to 0.72441, saving model to models/pima_indians/weights-improvement-17-0.72.hdf5
#
# Epoch 00018: val_accuracy did not improve from 0.72441
#
# Epoch 00019: val_accuracy did not improve from 0.72441
#
# Epoch 00020: val_accuracy did not improve from 0.72441
#
# Epoch 00021: val_accuracy did not improve from 0.72441
#
# Epoch 00022: val_accuracy did not improve from 0.72441
#
# Epoch 00023: val_accuracy did not improve from 0.72441
#
# Epoch 00024: val_accuracy did not improve from 0.72441
#
# Epoch 00025: val_accuracy did not improve from 0.72441
#
# Epoch 00026: val_accuracy did not improve from 0.72441
#
# Epoch 00027: val_accuracy did not improve from 0.72441
#
# Epoch 00028: val_accuracy did not improve from 0.72441
#
# Epoch 00029: val_accuracy did not improve from 0.72441
#
# Epoch 00030: val_accuracy did not improve from 0.72441
#
# Epoch 00031: val_accuracy did not improve from 0.72441
#
# Epoch 00032: val_accuracy did not improve from 0.72441
#
# Epoch 00033: val_accuracy did not improve from 0.72441
#
# Epoch 00034: val_accuracy did not improve from 0.72441
#
# Epoch 00035: val_accuracy did not improve from 0.72441
#
# Epoch 00036: val_accuracy did not improve from 0.72441
#
# Epoch 00037: val_accuracy did not improve from 0.72441
#
# Epoch 00038: val_accuracy did not improve from 0.72441
#
# Epoch 00039: val_accuracy did not improve from 0.72441
#
# Epoch 00040: val_accuracy did not improve from 0.72441
#
# Epoch 00041: val_accuracy did not improve from 0.72441
#
# Epoch 00042: val_accuracy did not improve from 0.72441
#
# Epoch 00043: val_accuracy did not improve from 0.72441
#
# Epoch 00044: val_accuracy did not improve from 0.72441
#
# Epoch 00045: val_accuracy did not improve from 0.72441
#
# Epoch 00046: val_accuracy did not improve from 0.72441
#
# Epoch 00047: val_accuracy did not improve from 0.72441
#
# Epoch 00048: val_accuracy did not improve from 0.72441
#
# Epoch 00049: val_accuracy did not improve from 0.72441
#
# Epoch 00050: val_accuracy did not improve from 0.72441
#
# Epoch 00051: val_accuracy did not improve from 0.72441
#
# Epoch 00052: val_accuracy did not improve from 0.72441
#
# Epoch 00053: val_accuracy improved from 0.72441 to 0.72835, saving model to models/pima_indians/weights-improvement-53-0.73.hdf5
#
# Epoch 00054: val_accuracy did not improve from 0.72835
#
# Epoch 00055: val_accuracy did not improve from 0.72835
#
# Epoch 00056: val_accuracy did not improve from 0.72835
#
# Epoch 00057: val_accuracy did not improve from 0.72835
#
# Epoch 00058: val_accuracy did not improve from 0.72835
#
# Epoch 00059: val_accuracy did not improve from 0.72835
#
# Epoch 00060: val_accuracy did not improve from 0.72835
#
# Epoch 00061: val_accuracy did not improve from 0.72835
#
# Epoch 00062: val_accuracy did not improve from 0.72835
#
# Epoch 00063: val_accuracy did not improve from 0.72835
#
# Epoch 00064: val_accuracy did not improve from 0.72835
#
# Epoch 00065: val_accuracy did not improve from 0.72835
#
# Epoch 00066: val_accuracy did not improve from 0.72835
#
# Epoch 00067: val_accuracy improved from 0.72835 to 0.74016, saving model to models/pima_indians/weights-improvement-67-0.74.hdf5
#
# Epoch 00068: val_accuracy did not improve from 0.74016
#
# Epoch 00069: val_accuracy did not improve from 0.74016
#
# Epoch 00070: val_accuracy did not improve from 0.74016
#
# Epoch 00071: val_accuracy did not improve from 0.74016
#
# Epoch 00072: val_accuracy did not improve from 0.74016
#
# Epoch 00073: val_accuracy did not improve from 0.74016
#
# Epoch 00074: val_accuracy improved from 0.74016 to 0.74803, saving model to models/pima_indians/weights-improvement-74-0.75.hdf5
#
# Epoch 00075: val_accuracy did not improve from 0.74803
#
# Epoch 00076: val_accuracy did not improve from 0.74803
#
# Epoch 00077: val_accuracy did not improve from 0.74803
#
# Epoch 00078: val_accuracy did not improve from 0.74803
#
# Epoch 00079: val_accuracy did not improve from 0.74803
#
# Epoch 00080: val_accuracy did not improve from 0.74803
#
# Epoch 00081: val_accuracy did not improve from 0.74803
#
# Epoch 00082: val_accuracy did not improve from 0.74803
#
# Epoch 00083: val_accuracy did not improve from 0.74803
#
# Epoch 00084: val_accuracy improved from 0.74803 to 0.75591, saving model to models/pima_indians/weights-improvement-84-0.76.hdf5
#
# Epoch 00085: val_accuracy did not improve from 0.75591
#
# Epoch 00086: val_accuracy did not improve from 0.75591
#
# Epoch 00087: val_accuracy did not improve from 0.75591
#
# Epoch 00088: val_accuracy did not improve from 0.75591
#
# Epoch 00089: val_accuracy did not improve from 0.75591
#
# Epoch 00090: val_accuracy did not improve from 0.75591
#
# Epoch 00091: val_accuracy did not improve from 0.75591
#
# Epoch 00092: val_accuracy did not improve from 0.75591
#
# Epoch 00093: val_accuracy did not improve from 0.75591
#
# Epoch 00094: val_accuracy did not improve from 0.75591
#
# Epoch 00095: val_accuracy did not improve from 0.75591
#
# Epoch 00096: val_accuracy did not improve from 0.75591
#
# Epoch 00097: val_accuracy did not improve from 0.75591
#
# Epoch 00098: val_accuracy did not improve from 0.75591
#
# Epoch 00099: val_accuracy did not improve from 0.75591
#
# Epoch 00100: val_accuracy did not improve from 0.75591
#
# Epoch 00101: val_accuracy improved from 0.75591 to 0.75984, saving model to models/pima_indians/weights-improvement-101-0.76.hdf5
#
# Epoch 00102: val_accuracy did not improve from 0.75984
#
# Epoch 00103: val_accuracy did not improve from 0.75984
#
# Epoch 00104: val_accuracy did not improve from 0.75984
#
# Epoch 00105: val_accuracy did not improve from 0.75984
#
# Epoch 00106: val_accuracy improved from 0.75984 to 0.76378, saving model to models/pima_indians/weights-improvement-106-0.76.hdf5
#
# Epoch 00107: val_accuracy did not improve from 0.76378
#
# Epoch 00108: val_accuracy did not improve from 0.76378
#
# Epoch 00109: val_accuracy did not improve from 0.76378
#
# Epoch 00110: val_accuracy did not improve from 0.76378
#
# Epoch 00111: val_accuracy did not improve from 0.76378
#
# Epoch 00112: val_accuracy did not improve from 0.76378
#
# Epoch 00113: val_accuracy did not improve from 0.76378
#
# Epoch 00114: val_accuracy did not improve from 0.76378
#
# Epoch 00115: val_accuracy did not improve from 0.76378
#
# Epoch 00116: val_accuracy did not improve from 0.76378
#
# Epoch 00117: val_accuracy did not improve from 0.76378
#
# Epoch 00118: val_accuracy improved from 0.76378 to 0.76772, saving model to models/pima_indians/weights-improvement-118-0.77.hdf5
#
# Epoch 00119: val_accuracy did not improve from 0.76772
#
# Epoch 00120: val_accuracy did not improve from 0.76772
#
# Epoch 00121: val_accuracy did not improve from 0.76772
#
# Epoch 00122: val_accuracy improved from 0.76772 to 0.77165, saving model to models/pima_indians/weights-improvement-122-0.77.hdf5
#
# Epoch 00123: val_accuracy did not improve from 0.77165
#
# Epoch 00124: val_accuracy improved from 0.77165 to 0.77559, saving model to models/pima_indians/weights-improvement-124-0.78.hdf5
#
# Epoch 00125: val_accuracy did not improve from 0.77559
#
# Epoch 00126: val_accuracy did not improve from 0.77559
# Epoch 00127: val_accuracy did not improve from 0.77559
#
# Epoch 00128: val_accuracy improved from 0.77559 to 0.77953, saving model to models/pima_indians/weights-improvement-128-0.78.hdf5
#
# Epoch 00129: val_accuracy did not improve from 0.77953
#
# Epoch 00130: val_accuracy did not improve from 0.77953
#
# Epoch 00131: val_accuracy did not improve from 0.77953
#
# Epoch 00132: val_accuracy did not improve from 0.77953
#
# Epoch 00133: val_accuracy did not improve from 0.77953
#
# Epoch 00134: val_accuracy did not improve from 0.77953
#
# Epoch 00135: val_accuracy did not improve from 0.77953
#
# Epoch 00136: val_accuracy did not improve from 0.77953
#
# Epoch 00137: val_accuracy did not improve from 0.77953
#
# Epoch 00138: val_accuracy did not improve from 0.77953
#
# Epoch 00139: val_accuracy did not improve from 0.77953
#
# Epoch 00140: val_accuracy did not improve from 0.77953
#
# Epoch 00141: val_accuracy did not improve from 0.77953
#
# Epoch 00142: val_accuracy did not improve from 0.77953
#
# Epoch 00143: val_accuracy did not improve from 0.77953
#
# Epoch 00144: val_accuracy did not improve from 0.77953
#
# Epoch 00145: val_accuracy did not improve from 0.77953
#
# Epoch 00146: val_accuracy did not improve from 0.77953
#
# Epoch 00147: val_accuracy did not improve from 0.77953
#
# Epoch 00148: val_accuracy did not improve from 0.77953
#
# Epoch 00149: val_accuracy did not improve from 0.77953
#
# Epoch 00150: val_accuracy did not improve from 0.77953

# %%
# best model saved to one single file
filepath = 'models/pima_indians/best_model.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.75197, saving model to models/pima_indians/best_model.hdf5
#
# Epoch 00002: val_accuracy did not improve from 0.75197
#
# Epoch 00003: val_accuracy did not improve from 0.75197
#
# Epoch 00004: val_accuracy improved from 0.75197 to 0.77559, saving model to models/pima_indians/best_model.hdf5
#
# Epoch 00005: val_accuracy did not improve from 0.77559
#
# Epoch 00006: val_accuracy did not improve from 0.77559
#
# Epoch 00007: val_accuracy did not improve from 0.77559
#
# Epoch 00008: val_accuracy did not improve from 0.77559
#
# Epoch 00009: val_accuracy improved from 0.77559 to 0.77953, saving model to models/pima_indians/best_model.hdf5
#
# Epoch 00010: val_accuracy improved from 0.77953 to 0.79134, saving model to models/pima_indians/best_model.hdf5
#
# Epoch 00011: val_accuracy did not improve from 0.79134
#
# Epoch 00012: val_accuracy did not improve from 0.79134
#
# Epoch 00013: val_accuracy did not improve from 0.79134
#
# Epoch 00014: val_accuracy did not improve from 0.79134
#
# Epoch 00015: val_accuracy did not improve from 0.79134
#
# Epoch 00016: val_accuracy did not improve from 0.79134
#
# Epoch 00017: val_accuracy did not improve from 0.79134
#
# Epoch 00018: val_accuracy did not improve from 0.79134
#
# Epoch 00019: val_accuracy did not improve from 0.79134
#
# Epoch 00020: val_accuracy did not improve from 0.79134
#
# Epoch 00021: val_accuracy did not improve from 0.79134
#
# Epoch 00022: val_accuracy did not improve from 0.79134
#
# Epoch 00023: val_accuracy did not improve from 0.79134
#
# Epoch 00024: val_accuracy did not improve from 0.79134
#
# Epoch 00025: val_accuracy did not improve from 0.79134
#
# Epoch 00026: val_accuracy did not improve from 0.79134
#
# Epoch 00027: val_accuracy did not improve from 0.79134
#
# Epoch 00028: val_accuracy did not improve from 0.79134
#
# Epoch 00029: val_accuracy did not improve from 0.79134
#
# Epoch 00030: val_accuracy did not improve from 0.79134
#
# Epoch 00031: val_accuracy did not improve from 0.79134
#
# Epoch 00032: val_accuracy did not improve from 0.79134
#
# Epoch 00033: val_accuracy did not improve from 0.79134
#
# Epoch 00034: val_accuracy did not improve from 0.79134
#
# Epoch 00035: val_accuracy did not improve from 0.79134
#
# Epoch 00036: val_accuracy did not improve from 0.79134
#
# Epoch 00037: val_accuracy did not improve from 0.79134
#
# Epoch 00038: val_accuracy did not improve from 0.79134
#
# Epoch 00039: val_accuracy did not improve from 0.79134
#
# Epoch 00040: val_accuracy did not improve from 0.79134
#
# Epoch 00041: val_accuracy did not improve from 0.79134
#
# Epoch 00042: val_accuracy did not improve from 0.79134
#
# Epoch 00043: val_accuracy did not improve from 0.79134
#
# Epoch 00044: val_accuracy did not improve from 0.79134
#
# Epoch 00045: val_accuracy did not improve from 0.79134
#
# Epoch 00046: val_accuracy did not improve from 0.79134
#
# Epoch 00047: val_accuracy did not improve from 0.79134
#
# Epoch 00048: val_accuracy did not improve from 0.79134
#
# Epoch 00049: val_accuracy did not improve from 0.79134
#
# Epoch 00050: val_accuracy did not improve from 0.79134
#
# Epoch 00051: val_accuracy did not improve from 0.79134
#
# Epoch 00052: val_accuracy did not improve from 0.79134
#
# Epoch 00053: val_accuracy did not improve from 0.79134
#
# Epoch 00054: val_accuracy did not improve from 0.79134
#
# Epoch 00055: val_accuracy did not improve from 0.79134
#
# Epoch 00056: val_accuracy did not improve from 0.79134
#
# Epoch 00057: val_accuracy did not improve from 0.79134
#
# Epoch 00058: val_accuracy did not improve from 0.79134
#
# Epoch 00059: val_accuracy did not improve from 0.79134
#
# Epoch 00060: val_accuracy did not improve from 0.79134
#
# Epoch 00061: val_accuracy did not improve from 0.79134
#
# Epoch 00062: val_accuracy improved from 0.79134 to 0.79921, saving model to models/pima_indians/best_model.hdf5
#
# Epoch 00063: val_accuracy did not improve from 0.79921
#
# Epoch 00064: val_accuracy did not improve from 0.79921
#
# Epoch 00065: val_accuracy did not improve from 0.79921
#
# Epoch 00066: val_accuracy did not improve from 0.79921
#
# Epoch 00067: val_accuracy did not improve from 0.79921
#
# Epoch 00068: val_accuracy did not improve from 0.79921
#
# Epoch 00069: val_accuracy did not improve from 0.79921
#
# Epoch 00070: val_accuracy did not improve from 0.79921
#
# Epoch 00071: val_accuracy did not improve from 0.79921
#
# Epoch 00072: val_accuracy did not improve from 0.79921
#
# Epoch 00073: val_accuracy did not improve from 0.79921
#
# Epoch 00074: val_accuracy did not improve from 0.79921
#
# Epoch 00075: val_accuracy did not improve from 0.79921
#
# Epoch 00076: val_accuracy did not improve from 0.79921
#
# Epoch 00077: val_accuracy did not improve from 0.79921
#
# Epoch 00078: val_accuracy did not improve from 0.79921
#
# Epoch 00079: val_accuracy did not improve from 0.79921
#
# Epoch 00080: val_accuracy did not improve from 0.79921
#
# Epoch 00081: val_accuracy did not improve from 0.79921
#
# Epoch 00082: val_accuracy did not improve from 0.79921
#
# Epoch 00083: val_accuracy did not improve from 0.79921
#
# Epoch 00084: val_accuracy did not improve from 0.79921
#
# Epoch 00085: val_accuracy did not improve from 0.79921
#
# Epoch 00086: val_accuracy did not improve from 0.79921
#
# Epoch 00087: val_accuracy did not improve from 0.79921
#
# Epoch 00088: val_accuracy did not improve from 0.79921
#
# Epoch 00089: val_accuracy did not improve from 0.79921
#
# Epoch 00090: val_accuracy did not improve from 0.79921
#
# Epoch 00091: val_accuracy did not improve from 0.79921
#
# Epoch 00092: val_accuracy did not improve from 0.79921
#
# Epoch 00093: val_accuracy did not improve from 0.79921
#
# Epoch 00094: val_accuracy did not improve from 0.79921
#
# Epoch 00095: val_accuracy did not improve from 0.79921
#
# Epoch 00096: val_accuracy did not improve from 0.79921
#
# Epoch 00097: val_accuracy did not improve from 0.79921
#
# Epoch 00098: val_accuracy did not improve from 0.79921
#
# Epoch 00099: val_accuracy did not improve from 0.79921
#
# Epoch 00100: val_accuracy did not improve from 0.79921
#
# Epoch 00101: val_accuracy did not improve from 0.79921
#
# Epoch 00102: val_accuracy did not improve from 0.79921
#
# Epoch 00103: val_accuracy did not improve from 0.79921
#
# Epoch 00104: val_accuracy did not improve from 0.79921
#
# Epoch 00105: val_accuracy did not improve from 0.79921
#
# Epoch 00106: val_accuracy did not improve from 0.79921
#
# Epoch 00107: val_accuracy did not improve from 0.79921
#
# Epoch 00108: val_accuracy did not improve from 0.79921
#
# Epoch 00109: val_accuracy did not improve from 0.79921
#
# Epoch 00110: val_accuracy did not improve from 0.79921
#
# Epoch 00111: val_accuracy did not improve from 0.79921
#
# Epoch 00112: val_accuracy did not improve from 0.79921
#
# Epoch 00113: val_accuracy did not improve from 0.79921
#
# Epoch 00114: val_accuracy did not improve from 0.79921
#
# Epoch 00115: val_accuracy did not improve from 0.79921
#
# Epoch 00116: val_accuracy did not improve from 0.79921
#
# Epoch 00117: val_accuracy did not improve from 0.79921
#
# Epoch 00118: val_accuracy did not improve from 0.79921
#
# Epoch 00119: val_accuracy did not improve from 0.79921
#
# Epoch 00120: val_accuracy did not improve from 0.79921
#
# Epoch 00121: val_accuracy did not improve from 0.79921
#
# Epoch 00122: val_accuracy did not improve from 0.79921
#
# Epoch 00123: val_accuracy did not improve from 0.79921
#
# Epoch 00124: val_accuracy did not improve from 0.79921
#
# Epoch 00125: val_accuracy did not improve from 0.79921
#
# Epoch 00126: val_accuracy did not improve from 0.79921
#
# Epoch 00127: val_accuracy did not improve from 0.79921
#
# Epoch 00128: val_accuracy did not improve from 0.79921
#
# Epoch 00129: val_accuracy did not improve from 0.79921
#
# Epoch 00130: val_accuracy did not improve from 0.79921
#
# Epoch 00131: val_accuracy did not improve from 0.79921
#
# Epoch 00132: val_accuracy did not improve from 0.79921
#
# Epoch 00133: val_accuracy did not improve from 0.79921
#
# Epoch 00134: val_accuracy did not improve from 0.79921
#
# Epoch 00135: val_accuracy did not improve from 0.79921
#
# Epoch 00136: val_accuracy did not improve from 0.79921
#
# Epoch 00137: val_accuracy did not improve from 0.79921
#
# Epoch 00138: val_accuracy did not improve from 0.79921
#
# Epoch 00139: val_accuracy did not improve from 0.79921
#
# Epoch 00140: val_accuracy did not improve from 0.79921
#
# Epoch 00141: val_accuracy did not improve from 0.79921
#
# Epoch 00142: val_accuracy did not improve from 0.79921
# Epoch 00143: val_accuracy did not improve from 0.79921
#
# Epoch 00144: val_accuracy did not improve from 0.79921
#
# Epoch 00145: val_accuracy did not improve from 0.79921
#
# Epoch 00146: val_accuracy did not improve from 0.79921
#
# Epoch 00147: val_accuracy did not improve from 0.79921
#
# Epoch 00148: val_accuracy did not improve from 0.79921
#
# Epoch 00149: val_accuracy did not improve from 0.79921
#
# Epoch 00150: val_accuracy did not improve from 0.79921
